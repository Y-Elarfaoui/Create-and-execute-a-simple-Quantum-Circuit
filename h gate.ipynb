# %% [markdown]
# <a href="https://colab.research.google.com/github/Y-Elarfaoui/Create-and-execute-a-simple-Quantum-Circuit/blob/main/h%20gate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from qiskit import QuantumCircuit

# %%
# !pip install qiskit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 50.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 58.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 MB 17.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.0/109.0 kB 7.3 MB/s eta 0:00:00
# ...

# %%
from qiskit import Aer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-5cf2fb0b7167> in <cell line: 0>()
# ----> 1 from qiskit import Aer
#
# ImportError: cannot import name 'Aer' from 'qiskit' (/usr/local/lib/python3.11/dist-packages/qiskit/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install qiskit

from IPython import get_ipython
from IPython.display import display
# %%
from qiskit import QuantumCircuit
# %%
# Import Aer from the correct submodule
from qiskit.providers.aer import Aer
# Out:
# ...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-6e77f9815556> in <cell line: 0>()
#       7 # %%
#       8 # Import Aer from the correct submodule
# ----> 9 from qiskit.providers.aer import Aer
#
# ModuleNotFoundError: No module named 'qiskit.providers.aer'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
circuit=quantumcircui(1,1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ae6735071e61> in <cell line: 0>()
# ----> 1 circuit=quantumcircui(1,1)
#
# NameError: name 'quantumcircui' is not defined

# %%
circuit.draw('mpl')

# %%
circuit.h(0)
circuit.draw('mpl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-11180077250a> in <cell line: 0>()
# ----> 1 circuit.h(0)
#       2 circuit.draw('mpl')
#
# NameError: name 'circuit' is not defined

# %%
circuit.measure(1,1)
circuit.draw('mpl')

# %%
backend=Aer.get.backend('qasm_sinulator')

# %%
job=backend.run(circuit)

# %%
result=job.result()get_counts()
# Out:
#   File "<ipython-input-13-93178c1fa9ee>", line 1
#     result=job.result()get_counts()
#                        ^
# SyntaxError: invalid syntax

# %%
from qiskit.visualization import plot_histogram
